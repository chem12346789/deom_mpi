# %%
data1 = fastread_np('./1d-corr-t.dat_0.4_1.0_40_1')
data2 = fastread_np('./prop-pol.dat_0.4_1.0_40_1')
plt.plot(data1[:,0], data1[:,1])
plt.plot(data2[:,0], data2[:,1], '--')
print(data1[:,1])
print(data2[:,1])
# plt.xlim(0, 1)
# Out:
# [2.260446e-01 2.257704e-01 2.254958e-01 ... 4.764109e-07 4.729557e-07
#  4.695104e-07]
# [2.26044609e-01 2.25770433e-01 2.25495769e-01 ... 4.76411047e-07
#  4.72955809e-07 4.69510436e-07]

# %%
plt.plot(np.fft.ifft(data1[:,1] +1.j*data1[:,2]))
plt.plot(np.fft.ifft(data2[:,1] +1.j*data2[:,2]),'--')
plt.xlim(0,100)
# Out:
# /home/dhem/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# /home/dhem/anaconda3/lib/python3.7/site-packages/numpy/core/_asarray.py:83: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)
# (0.0, 100.0)
